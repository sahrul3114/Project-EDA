# %% [markdown]
# <a href="https://colab.research.google.com/github/sahrul3114/Project-EDA/blob/main/Data_UAS_EDA_Kelompok_A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Kelompok A3 EDA**
# # Dashboard Analisis Data Penjualan dalam Perdagangan Online
# 1. Syahrul Akbar Ramdhani 1123094000027
# 2. Bagus Hari Pratomo 11230940000039
# 3. Muhammad Alwan Syechan 11230940000043
# 4. Farrel Gibran Keefy 11230940000065

# %%
# !wget --no-check-certificate 'https://drive.google.com/uc?export=download&id=1d5nTh88lVrLLNeKu6HPxmtHk7lTI09bD' -O "Global_Superstore2.csv"
# Out:
# --2025-04-19 14:29:45--  https://drive.google.com/uc?export=download&id=1d5nTh88lVrLLNeKu6HPxmtHk7lTI09bD
# Resolving drive.google.com (drive.google.com)... 74.125.134.101, 74.125.134.102, 74.125.134.139, ...
# Connecting to drive.google.com (drive.google.com)|74.125.134.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1d5nTh88lVrLLNeKu6HPxmtHk7lTI09bD&export=download [following]
# --2025-04-19 14:29:45--  https://drive.usercontent.google.com/download?id=1d5nTh88lVrLLNeKu6HPxmtHk7lTI09bD&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.212.132, 2607:f8b0:400c:c11::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.212.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12089916 (12M) [application/octet-stream]
# Saving to: ‘Global_Superstore2.csv’
#
# ...

# %%
# Membuat dataframe dari data csv
import pandas as pd
data = pd.read_csv('Global_Superstore2.csv', encoding='latin-1')
data
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4       47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470   US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
# 1. Tipe data setiap variabel
print("Tipe data setiap kolom:")
print(data.dtypes)

# 2. Ukuran total data
print("\nUkuran data (jumlah baris, jumlah kolom):")
print(data.shape)

# 3. Cek nilai yang hilang
print("\nJumlah nilai yang hilang di setiap kolom:")
print(data.isnull().sum())

# Kolom dengan proporsi nilai hilang terbesar
missing_data_ratio = data.isnull().mean().sort_values(ascending=False)
print("\nKolom dengan proporsi nilai hilang terbesar:")
print(missing_data_ratio)

# 4. Kualitas data dan noise
# Cek duplikasi data
print("\nJumlah duplikasi data:")
print(data.duplicated().sum())

# Statistik deskriptif untuk deteksi outlier atau noise
print("\nStatistik deskriptif data:")
data.describe(include)
# Out:
# Tipe data setiap kolom:
# Row ID                             int64
# Order ID                          object
# Order Date                datetime64[ns]
# Ship Date                 datetime64[ns]
# Ship Mode                         object
# Customer ID                       object
# Customer Name                     object
# Segment                           object
# City                              object
# State                             object
# Country                           object
# Market                            object
# Region                            object
# Product ID                        object
# Category                          object
# Sub-Category                      object
# Product Name                      object
# Sales                            float64
# Quantity                           int64
# Discount                         float64
# Profit                           float64
# Shipping Cost                    float64
# ...

# %%
# Menghapus kolom 'Postal Code' karena 80% datanya missing
data.drop(columns=['Postal Code'], inplace=True)

# %%
data
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4       47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470   US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
# Mengubah tipe data menjadi datetime
data['Order Date'] = pd.to_datetime(data['Order Date'], format='%d-%m-%Y')
data['Ship Date'] = pd.to_datetime(data['Ship Date'], format='%d-%m-%Y')

# %%
# Membuat kolom baru
data['Lama Pemrosesan (Hari)'] = (data['Ship Date'] - data['Order Date']).dt.days

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
# Menyimpan data
data.to_csv('processed_data.csv', encoding = 'utf-8', index=True)

# %%
from google.colab import files

# Mengunduh file CSV ke laptop
files.download('processed_data.csv')
